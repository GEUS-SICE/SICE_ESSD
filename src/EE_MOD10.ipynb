# %%
import ee
ee.Authenticate()

# Initialize the library.
ee.Initialize(project='sice-geus')

# %%
import geemap
import numpy as np
import glob
import os
import pandas as pd
from datetime import datetime, timedelta

# %%
data_folder = r'C:\Users\rabni\OneDrive - GEUS\MODIS\EE\MOD10A1\albedo_daily' 
re = 'Greenland' 

mo_to_do = ['04','05','06','07','08','09']
sday = '2017-04-01'
eday = '2023-10-02'

dates = pd.date_range(start=sday,end=eday).to_pydatetime().tolist()
dates = [d.strftime("%Y-%m-%d") for d in dates]
dates = [d for d in dates if d.split('-')[1] in mo_to_do]

data_files = glob.glob(data_folder + os.sep + re + os.sep + '*' + os.sep + '*.tif')
data_files_dates = [d.split(os.sep)[-1][:-4] for d in data_files] 
dates_to_do = [d for d in dates if d not in data_files_dates]

#print(dates_to_do) 

### Set up Polygon (maybe import) ###

greenland_vertices = [
      [-11.299,81.627],[-11.254,81.161],[-14.744,80.434],[-15.731,80.246],[-16.664,79.564],[-17.426,77.707],
      [-17.094,74.881],[-19.758,73.841],[-21.427,72.621],[-21.445,71.257],[-21.373,69.858],[-25.877,68.350],
      [-32.048,67.543],[-35.924,65.587],[-39.943,64.870],[-40.786,63.022],[-41.916,62.466],[-41.988,61.533],
      [-43.100,59.774],[-44.392,59.541],[-46.132,60.402],[-46.760,60.510],[-47.496,60.600],[-48.384,60.636],
      [-49.093,61.326],[-52.430,64.287],[-52.708,65.175],[-53.462,65.570],[-54.072,66.619],[-53.785,68.575],
      [-55.372,69.911],[-56.090,71.822],[-56.888,73.580],[-58.261,74.800],[-59.723,75.392],[-61.948,75.940],
      [-65.599,75.698],[-69.914,75.859],[-72.605,77.151],[-73.197,78.326],[-72.363,78.730],[-66.855,80.784],
      [-66.308,80.999],[-60.656,81.995],[-58.144,82.237],[-52.089,82.605],[-45.361,83.323],[-40.651,83.520],
      [-35.619,83.879],[-25.392,83.547],[-11.299,81.627],
  ]

# Create a polygon for Greenland using the specified vertices
greenland_polygon = ee.Geometry.Polygon(greenland_vertices)
#print('Greenland Polygon:', greenland_polygon.getInfo())
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
def add_one_day(original_date):
    
    # Convert the input string to a datetime object
    current_date = datetime.strptime(original_date, "%Y-%m-%d")
    # Add one day
    new_date = current_date + timedelta(days=1)
    # Format the result in "YYYY-MM-DD" format
    new_date_formatted = new_date.strftime("%Y-%m-%d")

    return new_date_formatted

for d in dates_to_do:

  date_start = d
  date_end = add_one_day(d)

  year = date_start[:4] 
  output_folder = data_folder+os.sep+re+os.sep+year
    
  # Function to mask clouds and snow
  def mask_clouds_snow(image):
      # Implement your cloud and snow masking logic here
      # Example: mask = image.select('some_band').eq(0)
      # return image.updateMask(mask)
      return image
      
  # Load MODIS albedo data
  albedo = (
      ee.ImageCollection('MODIS/061/MOD10A1')
      .filterBounds(greenland_polygon)
      .filterDate(ee.Date(date_start), ee.Date(date_end))
      .select(['Snow_Albedo_Daily_Tile'])
  )

  # Check the number of images in the collection
  count = albedo.size()
  print('Number of images in the collection:', count.getInfo())

  # Define the projection EPSG:3413
  projection_3413 = "EPSG:3413"

  # Reproject all images to EPSG:3413
  albedo_reprojected = albedo.map(lambda image: image.reproject(crs=projection_3413, scale=500))

  # Create a map with EPSG:3413 projection
  Map = geemap.Map(center=[70, -40], zoom=5)
  Map.add_basemap('SATELLITE')

  # Display the first reprojected image from the collection using geemap
  band_name = 'Snow_Albedo_Daily_Tile'

  first_image_reprojected = albedo.first()
  Map.addLayer(first_image_reprojected.clip(greenland_polygon).select(band_name), {'min': 0, 'max': 32766}, 'Albedo ' + band_name)
  # Add the Greenland polygon to the map
  Map.addLayer(greenland_polygon, {'color': 'FF0000'}, 'Greenland Polygon')
  dates = list(albedo_reprojected.aggregate_array('system:index').getInfo())

  # Export all reprojected images as GeoTIFF to local machine

 
  geemap.ee_export_image_collection(albedo_reprojected, out_dir=output_folder, region=greenland_polygon, scale=500, crs=projection_3413)
  # Display the map in the notebook
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Number of images in the collection: 1
# Total number of images: 1
#
# Exporting 1/1: C:\Users\rabni\OneDrive - GEUS\MODIS\EE\MOD10A1\albedo_daily\Greenland\2017\2017_04_01.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/sice-geus/thumbnails/75b4d71367b27c198a9c07b407d8e853-c94b19cc3f7f5ebd54736bb14365c423:getPixels
# Please wait ...
# Data downloaded to C:\Users\rabni\OneDrive - GEUS\MODIS\EE\MOD10A1\albedo_daily\Greenland\2017\2017_04_01.tif
#
#
# Number of images in the collection: 1
# Total number of images: 1
#
# Exporting 1/1: C:\Users\rabni\OneDrive - GEUS\MODIS\EE\MOD10A1\albedo_daily\Greenland\2017\2017_04_02.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/sice-geus/thumbnails/2608d9447b0db2759674d1deb2d01322-f4224f1a7d5222dcfec1146344033fbc:getPixels
# Please wait ...
# Data downloaded to C:\Users\rabni\OneDrive - GEUS\MODIS\EE\MOD10A1\albedo_daily\Greenland\2017\2017_04_02.tif
#
#
# Number of images in the collection: 1
# Total number of images: 1
#
# Exporting 1/1: C:\Users\rabni\OneDrive - GEUS\MODIS\EE\MOD10A1\albedo_daily\Greenland\2017\2017_04_03.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/sice-geus/thumbnails/829de1b227faadef20fca415df6138fb-44796ddbf79d315e1c2a2e1734f571d0:getPixels
# Please wait ...
# Data downloaded to C:\Users\rabni\OneDrive - GEUS\MODIS\EE\MOD10A1\albedo_daily\Greenland\2017\2017_04_03.tif
#
#
# Number of images in the collection: 1
# Total number of images: 1
#
# Exporting 1/1: C:\Users\rabni\OneDrive - GEUS\MODIS\EE\MOD10A1\albedo_daily\Greenland\2017\2017_04_04.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/sice-geus/thumbnails/ce626a4e712e6ceae3bdc2279398a995-87784e5f3ebc9eb84ba080af5bcbb2e4:getPixels
# Please wait ...
# Data downloaded to C:\Users\rabni\OneDrive - GEUS\MODIS\EE\MOD10A1\albedo_daily\Greenland\2017\2017_04_04.tif
#
#
# Number of images in the collection: 1
# Total number of images: 1
#
# Exporting 1/1: C:\Users\rabni\OneDrive - GEUS\MODIS\EE\MOD10A1\albedo_daily\Greenland\2017\2017_04_05.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/sice-geus/thumbnails/9308634f719a97a1d914f4df3a76f385-1ac5f0df48d59bbc344904722187f8ad:getPixels
# Please wait ...
# Data downloaded to C:\Users\rabni\OneDrive - GEUS\MODIS\EE\MOD10A1\albedo_daily\Greenland\2017\2017_04_05.tif
#
#
# Number of images in the collection: 1
# Total number of images: 1
#
# Exporting 1/1: C:\Users\rabni\OneDrive - GEUS\MODIS\EE\MOD10A1\albedo_daily\Greenland\2017\2017_04_06.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/sice-geus/thumbnails/3e3e48193101b7e5aa2f63cf0daa14fe-4b1f8fb66049171654ac7519965d4d5f:getPixels
# Please wait ...
# Data downloaded to C:\Users\rabni\OneDrive - GEUS\MODIS\EE\MOD10A1\albedo_daily\Greenland\2017\2017_04_06.tif
#
#
# Number of images in the collection: 1
# Total number of images: 1
#
# Exporting 1/1: C:\Users\rabni\OneDrive - GEUS\MODIS\EE\MOD10A1\albedo_daily\Greenland\2017\2017_04_07.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/sice-geus/thumbnails/71f0cb95a35741b4a42ddee8afe87944-94cfd391f4c77c894fa5e6a8ded5b7d3:getPixels
# Please wait ...
# Data downloaded to C:\Users\rabni\OneDrive - GEUS\MODIS\EE\MOD10A1\albedo_daily\Greenland\2017\2017_04_07.tif
#
#
# Number of images in the collection: 1
# Total number of images: 1
#
# Exporting 1/1: C:\Users\rabni\OneDrive - GEUS\MODIS\EE\MOD10A1\albedo_daily\Greenland\2017\2017_04_08.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/sice-geus/thumbnails/bafa9da7d4f25a0b45e4b7864df12039-5b2e1c40b0f91cc85bd7c1433ff7f870:getPixels
# Please wait ...
# Data downloaded to C:\Users\rabni\OneDrive - GEUS\MODIS\EE\MOD10A1\albedo_daily\Greenland\2017\2017_04_08.tif
#
#
# Number of images in the collection: 1
# Total number of images: 1
#
# Exporting 1/1: C:\Users\rabni\OneDrive - GEUS\MODIS\EE\MOD10A1\albedo_daily\Greenland\2017\2017_04_09.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/sice-geus/thumbnails/9823397e75122fe3cdefcb87110b6d26-a64c15491a551fdddef63a2cb69ce48a:getPixels
# Please wait ...
# Data downloaded to C:\Users\rabni\OneDrive - GEUS\MODIS\EE\MOD10A1\albedo_daily\Greenland\2017\2017_04_09.tif
#
#
# Number of images in the collection: 1
# Total number of images: 1
#
# Exporting 1/1: C:\Users\rabni\OneDrive - GEUS\MODIS\EE\MOD10A1\albedo_daily\Greenland\2017\2017_04_10.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/sice-geus/thumbnails/ea30c3ebe363f03c9e51ab4dabc0c070-01f06bca6c7f853f59a7998e83ce5278:getPixels
# Please wait ...
# Data downloaded to C:\Users\rabni\OneDrive - GEUS\MODIS\EE\MOD10A1\albedo_daily\Greenland\2017\2017_04_10.tif
#
#
# Number of images in the collection: 1
# Total number of images: 1
#
# Exporting 1/1: C:\Users\rabni\OneDrive - GEUS\MODIS\EE\MOD10A1\albedo_daily\Greenland\2017\2017_04_11.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/sice-geus/thumbnails/8b9119eeb9ae4cf838dfdb23d7ce4d17-78364751ed6ef8ddb7e9e3bc10686591:getPixels
# Please wait ...
# Data downloaded to C:\Users\rabni\OneDrive - GEUS\MODIS\EE\MOD10A1\albedo_daily\Greenland\2017\2017_04_11.tif
#
#
# Number of images in the collection: 1
# Total number of images: 1
#
# Exporting 1/1: C:\Users\rabni\OneDrive - GEUS\MODIS\EE\MOD10A1\albedo_daily\Greenland\2017\2017_04_12.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/sice-geus/thumbnails/dff0fd0fc3b94e93372a9a1b80c54acd-fed7d4151521643f00289394821dec23:getPixels
# Please wait ...
# Data downloaded to C:\Users\rabni\OneDrive - GEUS\MODIS\EE\MOD10A1\albedo_daily\Greenland\2017\2017_04_12.tif
#
#
# Number of images in the collection: 1
# Total number of images: 1
#
# Exporting 1/1: C:\Users\rabni\OneDrive - GEUS\MODIS\EE\MOD10A1\albedo_daily\Greenland\2017\2017_04_13.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/sice-geus/thumbnails/02d3d1f2de720175f6ce49d2ea34094f-0bd5b2ac0a315c397273318e2ae7889d:getPixels
# Please wait ...
# Data downloaded to C:\Users\rabni\OneDrive - GEUS\MODIS\EE\MOD10A1\albedo_daily\Greenland\2017\2017_04_13.tif
#
#
# Number of images in the collection: 1
# Total number of images: 1
#
# Exporting 1/1: C:\Users\rabni\OneDrive - GEUS\MODIS\EE\MOD10A1\albedo_daily\Greenland\2017\2017_04_14.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/sice-geus/thumbnails/727b2cfb20390be738a160d06302ec43-4f48186443469deb546c6ba783bc8f8d:getPixels
# Please wait ...
# Data downloaded to C:\Users\rabni\OneDrive - GEUS\MODIS\EE\MOD10A1\albedo_daily\Greenland\2017\2017_04_14.tif
#
#
# Number of images in the collection: 1
# Total number of images: 1
#
# Exporting 1/1: C:\Users\rabni\OneDrive - GEUS\MODIS\EE\MOD10A1\albedo_daily\Greenland\2017\2017_04_15.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/sice-geus/thumbnails/d5df243585b32e898d8dd1741a726d8a-7bea06f0f09ccfeb51864d71e7bba435:getPixels
# Please wait ...
# Data downloaded to C:\Users\rabni\OneDrive - GEUS\MODIS\EE\MOD10A1\albedo_daily\Greenland\2017\2017_04_15.tif
#
#
# Number of images in the collection: 1
# Total number of images: 1
#
# Exporting 1/1: C:\Users\rabni\OneDrive - GEUS\MODIS\EE\MOD10A1\albedo_daily\Greenland\2017\2017_04_16.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/sice-geus/thumbnails/2e160c1ef78d00981b5604eec78b39d9-202b421d328af313db2c06e1711ff975:getPixels
# Please wait ...
# Data downloaded to C:\Users\rabni\OneDrive - GEUS\MODIS\EE\MOD10A1\albedo_daily\Greenland\2017\2017_04_16.tif
#
#
# Number of images in the collection: 1
# Total number of images: 1
#
# Exporting 1/1: C:\Users\rabni\OneDrive - GEUS\MODIS\EE\MOD10A1\albedo_daily\Greenland\2017\2017_04_17.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/sice-geus/thumbnails/42b0e528ded3203833fe3c2a85787c41-c95bd7370ecc8f259c61b1ce1fee4d6b:getPixels
# Please wait ...
# Data downloaded to C:\Users\rabni\OneDrive - GEUS\MODIS\EE\MOD10A1\albedo_daily\Greenland\2017\2017_04_17.tif
#
#
# Number of images in the collection: 1
# Total number of images: 1
#
# Exporting 1/1: C:\Users\rabni\OneDrive - GEUS\MODIS\EE\MOD10A1\albedo_daily\Greenland\2017\2017_04_18.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/sice-geus/thumbnails/88405d3332bf3f0389f1f0536f2d63d8-23a3823b67b54fb7f59dfb9b2c66301d:getPixels
# Please wait ...
# Data downloaded to C:\Users\rabni\OneDrive - GEUS\MODIS\EE\MOD10A1\albedo_daily\Greenland\2017\2017_04_18.tif
#
#
# Number of images in the collection: 1
# Total number of images: 1
#
# Exporting 1/1: C:\Users\rabni\OneDrive - GEUS\MODIS\EE\MOD10A1\albedo_daily\Greenland\2017\2017_04_19.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/sice-geus/thumbnails/78011ac40015dc19ca195c5d58a695a7-fa532362ac663903837bfbad4faf307c:getPixels
# Please wait ...
# Data downloaded to C:\Users\rabni\OneDrive - GEUS\MODIS\EE\MOD10A1\albedo_daily\Greenland\2017\2017_04_19.tif
#
#
# Number of images in the collection: 1
# Total number of images: 1
#
# Exporting 1/1: C:\Users\rabni\OneDrive - GEUS\MODIS\EE\MOD10A1\albedo_daily\Greenland\2017\2017_04_20.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/sice-geus/thumbnails